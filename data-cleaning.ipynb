# %%
import pandas as pd

# %%
DF = pd.read_csv("C:/Users/Saeed Ahmad/Desktop/Fifa_world_cup_matches.csv")

# %% [markdown]
# ## Display the first few rows of the dataset

# %%
print(DF.head())
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#   possession in contest  number of goals team1  number of goals team2  \
# 0                    8%                      0                      2
# 1                    9%                      6                      2
# 2                   11%                      0                      2
# 3                   10%                      1                      1
# 4                   12%                      1                      2
#
#         date   hour category  ...  penalties scored team1  \
# 0  20-Nov-22  17:00  Group A  ...                       0
# ...

# %%
# Check the data types and missing values
print(DF.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %%
# Summary statistics
print(DF.describe())
# Out:
#        number of goals team1  number of goals team2  total attempts team1  \
# count              64.000000              64.000000             64.000000
# mean                1.578125               1.109375             11.140625
# std                 1.551289               1.055856              4.972519
# min                 0.000000               0.000000              2.000000
# 25%                 0.000000               0.000000              8.000000
# 50%                 1.000000               1.000000             10.000000
# 75%                 2.000000               2.000000             14.000000
# max                 7.000000               4.000000             25.000000
#
#        total attempts team2  conceded team1  conceded team2  \
# count             64.000000       64.000000       64.000000
# mean              11.281250        1.109375        1.578125
# std                5.807682        1.055856        1.551289
# ...

# %%
# use the colums need to be used.
df = DF[['team1', 'team2', 'possession team1', 'possession team2', 'number of goals team1',
       'number of goals team2', 'date', 'hour', 'category',
       'total attempts team1', 'total attempts team2',  'assists team1', 'assists team2',
       'on target attempts team1', 'on target attempts team2',
       'off target attempts team1', 'off target attempts team2']].copy()

# %%
#To check the data types of the columns
df.dtypes
# Out:
# team1                        object
# team2                        object
# possession team1             object
# possession team2             object
# number of goals team1         int64
# number of goals team2         int64
# date                         object
# hour                         object
# category                     object
# total attempts team1          int64
# total attempts team2          int64
# assists team1                 int64
# assists team2                 int64
# on target attempts team1      int64
# on target attempts team2      int64
# off target attempts team1     int64
# off target attempts team2     int64
# dtype: object

# %%
df.head(5)
# Out:
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#    number of goals team1  number of goals team2       date   hour category  \
# 0                      0                      2  20-Nov-22  17:00  Group A
# 1                      6                      2  21-Nov-22  14:00  Group B
# 2                      0                      2  21-Nov-22  17:00  Group A
# 3                      1                      1  21-Nov-22  20:00  Group B
# 4                      1                      2  22-Nov-22  11:00  Group C
#
#    total attempts team1  total attempts team2  assists team1  assists team2  \
# ...

# %%
#change the date column
df.date = pd.to_datetime(df.date)
df.head()
# Out:
# C:\Users\Saeed Ahmad\AppData\Local\Temp\ipykernel_38220\400548711.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df.date = pd.to_datetime(df.date)
#            team1         team2 possession team1 possession team2  \
# 0          QATAR       ECUADOR              42%              50%
# 1        ENGLAND          IRAN              72%              19%
# 2        SENEGAL   NETHERLANDS              44%              45%
# 3  UNITED STATES         WALES              51%              39%
# 4      ARGENTINA  SAUDI ARABIA              64%              24%
#
#    number of goals team1  number of goals team2       date   hour category  \
# 0                      0                      2 2022-11-20  17:00  Group A
# 1                      6                      2 2022-11-21  14:00  Group B
# ...

# %%
# chane possession team1 column to int
df['possession team1'] = df['possession team1'].str.replace('%', '').astype(int)

# Display the modified DataFrame
df.head(5)
# Out:
#            team1         team2  possession team1 possession team2  \
# 0          QATAR       ECUADOR                42              50%
# 1        ENGLAND          IRAN                72              19%
# 2        SENEGAL   NETHERLANDS                44              45%
# 3  UNITED STATES         WALES                51              39%
# 4      ARGENTINA  SAUDI ARABIA                64              24%
#
#    number of goals team1  number of goals team2       date   hour category  \
# 0                      0                      2 2022-11-20  17:00  Group A
# 1                      6                      2 2022-11-21  14:00  Group B
# 2                      0                      2 2022-11-21  17:00  Group A
# 3                      1                      1 2022-11-21  20:00  Group B
# 4                      1                      2 2022-11-22  11:00  Group C
#
#    total attempts team1  total attempts team2  assists team1  assists team2  \
# ...

# %%
# chane possession team2 column to int
df['possession team2'] = df['possession team2'].str.replace('%', '').astype(int)

# Display the modified DataFrame
df.head(5)
# Out:
#            team1         team2  possession team1  possession team2  \
# 0          QATAR       ECUADOR                42                50
# 1        ENGLAND          IRAN                72                19
# 2        SENEGAL   NETHERLANDS                44                45
# 3  UNITED STATES         WALES                51                39
# 4      ARGENTINA  SAUDI ARABIA                64                24
#
#    number of goals team1  number of goals team2       date   hour category  \
# 0                      0                      2 2022-11-20  17:00  Group A
# 1                      6                      2 2022-11-21  14:00  Group B
# 2                      0                      2 2022-11-21  17:00  Group A
# 3                      1                      1 2022-11-21  20:00  Group B
# 4                      1                      2 2022-11-22  11:00  Group C
#
#    total attempts team1  total attempts team2  assists team1  assists team2  \
# ...

# %%
# check if there are empty or blank spaces

null_values = df.isnull().sum()
null_values
# Out:
# team1                        0
# team2                        0
# possession team1             0
# possession team2             0
# number of goals team1        0
# number of goals team2        0
# date                         0
# hour                         0
# category                     0
# total attempts team1         0
# total attempts team2         0
# assists team1                0
# assists team2                0
# on target attempts team1     0
# on target attempts team2     0
# off target attempts team1    0
# off target attempts team2    0
# dtype: int64
